# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

# %% [markdown]
# # ans1

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.shine.com/')

# %%
designation=driver.find_element(By.CLASS_NAME,"input")
designation.send_keys('data scientist')

# %%
search=driver.find_element(By.CLASS_NAME,"iconH-zoom-white")
search.click()

# %%
ac=driver.find_element(By.CLASS_NAME,"form-control  ")
ac.send_keys('data analyst')

# %%
fg=driver.find_element(By.XPATH,'/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input')
fg.send_keys('Bangalore')

# %%
sear=driver.find_element(By.XPATH,'/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[2]/div/button')
sear.click()

# %%
job_title=[]

# %%
job=driver.find_elements(By.XPATH,'/html/body/div[1]/div[1]/div[4]/div/div[2]/div[1]/div/div/div[1]/div[1]/div[1]/h2/a')
for i in job:
    title=i.text
    job_title.append(title)

# %%
job_title
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="320fa78a60edabed1644d7b24d861db6", element="3F1B4721446AC148FF7E6213C346702A_element_6947")>,
#  'Data Analyst Recruitment']

# %% [markdown]
# # ans4

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.flipkart.com/')

# %%
product=driver.find_element(By.CLASS_NAME,"Pke_EE")
product.send_keys("sunglasses")

# %%
search=driver.find_element(By.CLASS_NAME,"_2iLD__")
search.click()

# %%
brand=[]
product_description=[]
price=[]

# %%
brands=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brands:
    res=i.text
    brand.append(res)

# %%
product_description=driver.find_elements(By.CLASS_NAME,"IRpwTa")
for i in product_description:
    result=i.text
    product_description.append(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 product_description=driver.find_elements(By.CLASS_NAME,"IRpwTa")
#       2 for i in product_description:
# ----> 3     result=i.text
#       4     product_description.append(result)
#
# AttributeError: 'str' object has no attribute 'text'

# %%
prices=driver.find_elements(By.CLASS_NAME,"_30jeq3")
for i in prices:
    result=i.text
    price.append(result)

# %%
data=pd.DataFrame({'brand':brand,})
data
# Out:
#             brand
# 0    Silver Kartz
# 1       ROYAL SON
# 2            SRPM
# 3        Fastrack
# 4            SRPM
# 5        Fastrack
# 6       ALFATOORE
# 7   VINCENT CHASE
# 8         ROADWAY
# 9         PC STAR
# 10  VINCENT CHASE
# 11   Singco India
# 12      Elligator
# 13        STACTOR
# 14          NuVew
# 15         PIRASO
# 16  VINCENT CHASE
# 17  VINCENT CHASE
# 18       DEPARTED
# 19        ROADWAY
# 20      ROYAL SON
# 21      ROYAL SON
# 22      Rich Club
# 23        ROADWAY
# 24         PIRASO
# 25      Rich Club
# 26  VINCENT CHASE
# 27  VINCENT CHASE
# 28       GANGSTAA
# 29      Elligator
# 30      ROYAL SON
# 31      ROYAL SON
# 32   Singco India
# 33      Rich Club
# 34    Syn Traders
# 35      Elligator
# 36   Singco India
# 37    john jacobs
# 38      ROYAL SON
# 39         PIRASO

# %% [markdown]
# # ans6

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.flipkart.com/')

# %%
product=driver.find_element(By.CLASS_NAME,"Pke_EE")
product.send_keys("sneakers")

# %%
search=driver.find_element(By.CLASS_NAME,"_2iLD__")
search.click()

# %%
brandss=[]
product_Description=[]
prices=[]

# %%
brands=driver.find_elements(By.CLASS_NAME,"_2WkVRV")
for i in brands:
    content=i.text
    brandss.append(content)

# %%
product=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in product:
    res=i.text
    product_Description.append(res)

# %%
product_Description
# Out:
# ['Combo Pack Of 2 Casual Shoes Sneakers For Men',
#  'Combo Pack Of 2 Casual Shoes Sneakers For Men',
#  'Trending Stylish Casual Outdoor Sneakers Shoes For Men ...',
#  'Sneakers For Women',
#  'Rungryp Sneakers For Men',
#  'Casual Sneakers ColourFul Block Shoes For Boys And Men ...',
#  'Combo pack of 2 Trendy Men’s Casual Shoes Sneakers For ...',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Lightweight,Comfort,Summer,Trendy,Walking,Outdoor,Styli...',
#  'Lightweight,Comfort,Summer,Trendy,Walking,Outdoor,Styli...',
#  'Mesh| Lightweight| Premiun| Comfort| Summer Tendy| Outd...',
#  'Sneakers For Men',
#  'Hustle V2 Sneakers For Men',
#  'Zod Runner V3 Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Casual Stylish Trending Sneakers For Women',
#  'Sneakers For Men',
#  'Alpha Predator Sneakers For Men',
#  'Casual Sneakrs For Men Sneakers For Men',
#  'Sneakers For Men',
#  'Synthetic Leather |Lightweight|Comfort|Summer|Trendy|Wa...',
# ...

# %%
len(product_Description)
# Out:
# 40

# %%
price=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price:
    result=i.text
    prices.append(result)

# %%
dataframe=pd.DataFrame({'brands':brandss,'product_description':product_Description,'prices':prices})
dataframe
# Out:
#                    brands                                product_description  \
# 0                  BRUTON      Combo Pack Of 2 Casual Shoes Sneakers For Men
# 1                  BRUTON      Combo Pack Of 2 Casual Shoes Sneakers For Men
# 2                URBANBOX  Trending Stylish Casual Outdoor Sneakers Shoes...
# 3               Deals4you                                 Sneakers For Women
# 4                    PUMA                           Rungryp Sneakers For Men
# 5                  Labbin  Casual Sneakers ColourFul Block Shoes For Boys...
# 6                  BRUTON  Combo pack of 2 Trendy Men’s Casual Shoes Snea...
# 7                  lejano                                   Sneakers For Men
# 8                     MAX                                   Sneakers For Men
# 9                Nobelite  Lightweight,Comfort,Summer,Trendy,Walking,Outd...
# 10                   aadi  Lightweight,Comfort,Summer,Trendy,Walking,Outd...
# ...

# %% [markdown]
# # ans7

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.amazon.in/')

# %%
product=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
product.send_keys("Laptop")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search.click()

# %%
intel7=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[7]/span[10]/li/span/a/div/label/i")
intel7.click()

# %%
title=[]
rating=[]
price=[]

# %%
titles=driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in titles:
    samp=i.text
    title.append(samp)

# %%
prices=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in prices:
    rupee=i.text
    price.append(rupee)

# %%
data=pd.DataFrame({'title':title,'prices':price})
data
# Out:
#                                                 title    prices
# 0   ASUS TUF Gaming F15, 15.6"(39.62 cms) FHD 144H...    75,990
# 1   ASUS TUF Gaming F15, 15.6"(39.62 cms) FHD 144H...    49,990
# 2   MSI Modern 14, Intel 12th Gen. i7-1255U, 36CM ...    64,990
# 3   MSI GF63 Thin, Intel Core i7-11800H, 40CM FHD ...    55,990
# 4   Lenovo IdeaPad Slim 3 Intel Core i7 11th Gen 1...    81,990
# 5   Samsung Galaxy Book3 Core i7 13th Gen 1355U - ...    60,990
# 6   ASUS Vivobook 15, IntelCore i7-12650H 12th Gen...    49,990
# 7   Acer Aspire Lite Premium Metal Laptop 11th Gen...    67,990
# 8   HP Laptop 15s, 12th Gen Intel Core i7-1255U, 1...    86,490
# 9   HP Windows 11 Home Victus Gaming Laptop,12Th G...    51,841
# 10  (Refurbished) ASUS Vivobook 15, IntelCore i7-1...    86,490
# 11  Dell Inspiron 5430 Laptop, Intel Core i7-1360P...  1,14,990
# 12  Acer Predator Helios Neo 16 Gaming Laptop 13th...    85,990
# 13  ASUS TUF Gaming F15, 15.6-inch (39.62 cms) FHD...    52,499
# ...

# %% [markdown]
# # ans5

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.flipkart.com/')

# %%
product=driver.find_element(By.CLASS_NAME,"Pke_EE")
product.send_keys("iphone11")

# %%
search=driver.find_element(By.CLASS_NAME,"_2iLD__")
search.click()

# %%
iphone=driver.find_element(By.XPATH,'//div[@class="_4rR01T"]')
iphone.click()

# %%
rating=[]
review_summary=[]
full_review=[]

# %%
rate=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rate:
    match=i.text
    rating.append(match)

# %%
review=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in review:
    gh=i.text
    review_summary.append(gh)

# %%
ful=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]/div/div')
for i in ful:
    rt=i.text
    full_review.append(rt)

# %%
data=pd.DataFrame({'rating':rating,'review_summary':review_summary})
data
# Out:
#   rating      review_summary
# 0      5      Classy product
# 1      4     Worth the money
# 2      5  Highly recommended
# 3      5    Perfect product!
# 4      5           Wonderful
# 5      5       Great product

# %% [markdown]
# # ans10

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.motor1.com/')

# %%
products=driver.find_element(By.XPATH,'/html/body/div[10]/div[2]/div/div/div[3]/div/div/div/form/input')
products.send_keys('50 most expensive cars')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[10]/div[2]/div/div/div[3]/div/div/div/form/button[1]')
search.click()

# %%
serch1=driver.find_element(By.XPATH,'/html/body/div[10]/div[9]/div/div[1]/div/div/div[2]/div/div[1]')
serch1.click()

# %%
expansive_brand=[]
price=[]

# %%
carbrand=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in carbrand:
    fg=i.text
    expansive_brand.append(fg)

# %%
dataframe=pd.DataFrame({'50 most expansive brand':expansive_brand})
dataframe
# Out:
#                50 most expansive brand
# 0                  Aston Martin Valour
# 1                         McLaren Elva
# 2                          Czinger 21C
# 3                        Ferrari Monza
# 4                   Gordon Murray T.33
# 5                    Koenigsegg Gemera
# 6                          Zenvo TSR-S
# 7                   Hennessey Venom F5
# 8                      Bentley Bacalar
# 9        Hispano Suiza Carmen Boulogne
# 10              Bentley Mulliner Batur
# 11                        Deus Vayanne
# 12                         SSC Tuatara
# 13                         Lotus Evija
# 14                 Aston Martin Vulcan
# 15                          Delage D12
# 16                 Ferrari Daytona SP3
# 17                   McLaren Speedtail
# 18                        Rimac Nevera
# 19                       Pagani Utopia
# 20                Pininfarina Battista
# 21                  Gordon Murray T.50
# 22                Lamborghini Countach
# ...
